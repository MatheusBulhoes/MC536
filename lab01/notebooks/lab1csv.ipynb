# %%
import pandas as pd
import io
import requests
url = "https://apps.who.int/gho/athena/api/GHO/WHS3_51?filter=YEAR:2010&format=csv"
data = requests.get(url).content
csv = io.StringIO(data.decode("utf-8"))
csv_read = pd.read_csv(csv, index_col="COUNTRY")
print(csv_read)
# Out:
#              GHO PUBLISHSTATE  YEAR REGION WORLDBANKINCOMEGROUP  \
# COUNTRY
# CHN      WHS3_51    PUBLISHED  2010    WPR               WB_LMI
# KHM      WHS3_51    PUBLISHED  2010    WPR                WB_LI
# EGY      WHS3_51    PUBLISHED  2010    EMR               WB_LMI
# IDN      WHS3_51    PUBLISHED  2010   SEAR               WB_LMI
# VNM      WHS3_51    PUBLISHED  2010    WPR                WB_LI
# NaN      WHS3_51    PUBLISHED  2010    WPR                  NaN
#
#          Display Value  Numeric  Low  High  Comments
# COUNTRY
# CHN                  2      NaN  NaN   NaN       NaN
# KHM                  1      NaN  NaN   NaN       NaN
# EGY                 29      NaN  NaN   NaN       NaN
# IDN                  9      NaN  NaN   NaN       NaN
# VNM                  7      NaN  NaN   NaN       NaN
# NaN                 10      NaN  NaN   NaN       NaN
